# %%
from news.preprocess.preprocess_link import NewsPreprocessor
from news.preprocess.preprocess_title import TitlePreprocessor
import pymongo
import pandas as pd

df = pd.read_csv('english_dataset.csv')
df = df[['id', 'title', 'link', 'province', 'source_link', 'credibility', 'name', 'source', 'date_published', 'full_title']]
df
# Out:
#                                                       id  \
# 0      CBMiZWh0dHBzOi8vaGFyaWFubnVzYS5jb20vMjAyMC8wMy...
# 1      CBMicGh0dHBzOi8vYmFudGVuLmFudGFyYW5ld3MuY29tL2...
# 2      CBMigwFodHRwczovL21ha2Fzc2FyLnRyaWJ1bm5ld3MuY2...
# 3      CBMiLGh0dHBzOi8vd3d3LmJiYy5jb20vaW5kb25lc2lhL2...
# 4      CBMiUWh0dHBzOi8va2FiYXIyNC5iaXNuaXMuY29tL3JlYW...
# ...                                                  ...
# 10409  CBMipQFodHRwczovL21lZGFuYmlzbmlzZGFpbHkuY29tL2...
# 10410  CBMiXGh0dHBzOi8vYmFsaWNpdGl6ZW4uY29tL2hpdHVuZ2...
# 10411  CBMib2h0dHBzOi8vY2VuZHJhd2FzaWgtbmV3cy5jb20vaX...
# 10412  CBMidmh0dHBzOi8vd3d3LmNuYmNpbmRvbmVzaWEuY29tL2...
# 10413  CBMifWh0dHBzOi8vamFtYmkudHJpYnVubmV3cy5jb20vMj...
#
#                                                    title  \
# 0      Antisipasi Penyebaran Covid-19, Unram Liburkan...
# 1      Pemprov Banten siapkan lima rumah sakit rujuka...
# 2      Cegah Covid-19, Pemerintah Desa Tangru Enrekan...
# ...

# %%
from model.predict import PredictLabel

# %%
title = df.iloc[0]['full_title']

# %%
model_path = "C:/Users/acer/OneDrive - The University of Manchester/Coding-dissertation/dissertation/model/save/20230809204219"
predictor = PredictLabel(model_path)
entities = predictor.get_entities_result(title)
print(entities)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\acer\OneDrive - The University of Manchester\Coding-dissertation\dissertation\initial_news_data.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/acer/OneDrive%20-%20The%20University%20of%20Manchester/Coding-dissertation/dissertation/initial_news_data.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> model_path = "C:/Users/acer/OneDrive - The University of Manchester/Coding-dissertation/dissertation/model/save/20230809204219"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/acer/OneDrive%20-%20The%20University%20of%20Manchester/Coding-dissertation/dissertation/initial_news_data.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> predictor = PredictLabel(model_path)
# ...
